# %%
import numpy as np
import pandas as pd
import tensorflow as tn

# %%
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
dataset=pd.read_csv('Crop_recommendation (1).csv')

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values
le=LabelEncoder()
y[:]=le.fit_transform(y[:])
le_name=dict(zip(le.classes_,le.transform(le.classes_)))
print(le_name)
# Out:
# {'apple': 0, 'banana': 1, 'blackgram': 2, 'chickpea': 3, 'coconut': 4, 'coffee': 5, 'cotton': 6, 'grapes': 7, 'jute': 8, 'kidneybeans': 9, 'lentil': 10, 'maize': 11, 'mango': 12, 'mothbeans': 13, 'mungbean': 14, 'muskmelon': 15, 'orange': 16, 'pigeonpeas': 17, 'pomegranate': 18, 'rice': 19, 'watermelon': 20}

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
X_scale = min_max_scaler.fit_transform(x)
y = np.asarray(y).astype('float32')
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test=train_test_split(x,y,test_size=.2, random_state=33)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (1679, 7)
# (1679,)

# %%
ann=tn.keras.models.Sequential()
ann.add(tn.keras.layers.Dense(units=44,activation='elu'))
ann.add(tn.keras.layers.Dense(units=44,activation='elu'))
ann.add(tn.keras.layers.Dense(units=22,activation='softmax'))
ann.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist=ann.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=30,epochs =100)
y_pre=ann.predict(x_test)
print(y_pre.size)
print(y_pre)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 1s 7ms/step - loss: 11.4323 - accuracy: 0.1614 - val_loss: 2.7615 - val_accuracy: 0.2357
# Epoch 2/100
# 56/56 [==============================] - 0s 3ms/step - loss: 1.6070 - accuracy: 0.4675 - val_loss: 0.9551 - val_accuracy: 0.6548
# Epoch 3/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.7394 - accuracy: 0.7439 - val_loss: 0.5489 - val_accuracy: 0.8167
# Epoch 4/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.4614 - accuracy: 0.8594 - val_loss: 0.3903 - val_accuracy: 0.8833
# Epoch 5/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.3537 - accuracy: 0.8886 - val_loss: 0.3287 - val_accuracy: 0.8833
# Epoch 6/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.2829 - accuracy: 0.9095 - val_loss: 0.2921 - val_accuracy: 0.8833
# Epoch 7/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.2484 - accuracy: 0.9184 - val_loss: 0.2346 - val_accuracy: 0.9214
# Epoch 8/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.2216 - accuracy: 0.9297 - val_loss: 0.1972 - val_accuracy: 0.9333
# Epoch 9/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.2115 - accuracy: 0.9261 - val_loss: 0.1619 - val_accuracy: 0.9429
# Epoch 10/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.1590 - accuracy: 0.9506 - val_loss: 0.2027 - val_accuracy: 0.9190
# Epoch 11/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.1754 - accuracy: 0.9387 - val_loss: 0.1631 - val_accuracy: 0.9476
# Epoch 12/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.1388 - accuracy: 0.9571 - val_loss: 0.1523 - val_accuracy: 0.9452
# Epoch 13/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.1423 - accuracy: 0.9559 - val_loss: 0.1466 - val_accuracy: 0.9619
# Epoch 14/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.1621 - accuracy: 0.9506 - val_loss: 0.1660 - val_accuracy: 0.9310
# Epoch 15/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.1619 - accuracy: 0.9428 - val_loss: 0.1579 - val_accuracy: 0.9357
# Epoch 16/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.1250 - accuracy: 0.9577 - val_loss: 0.1254 - val_accuracy: 0.9643
# Epoch 17/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.1233 - accuracy: 0.9553 - val_loss: 0.1174 - val_accuracy: 0.9476
# Epoch 18/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.1197 - accuracy: 0.9589 - val_loss: 0.1469 - val_accuracy: 0.9333
# Epoch 19/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1188 - accuracy: 0.9607 - val_loss: 0.1332 - val_accuracy: 0.9500
# Epoch 20/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1150 - accuracy: 0.9607 - val_loss: 0.1483 - val_accuracy: 0.9476
# Epoch 21/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.1083 - accuracy: 0.9631 - val_loss: 0.1115 - val_accuracy: 0.9619
# Epoch 22/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.1060 - accuracy: 0.9637 - val_loss: 0.1169 - val_accuracy: 0.9500
# Epoch 23/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0967 - accuracy: 0.9643 - val_loss: 0.1038 - val_accuracy: 0.9643
# Epoch 24/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0905 - accuracy: 0.9696 - val_loss: 0.0957 - val_accuracy: 0.9667
# Epoch 25/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0913 - accuracy: 0.9684 - val_loss: 0.1097 - val_accuracy: 0.9714
# Epoch 26/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1107 - accuracy: 0.9577 - val_loss: 0.1156 - val_accuracy: 0.9524
# Epoch 27/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9661 - val_loss: 0.1201 - val_accuracy: 0.9667
# Epoch 28/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.1065 - accuracy: 0.9583 - val_loss: 0.1132 - val_accuracy: 0.9500
# Epoch 29/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1013 - accuracy: 0.9684 - val_loss: 0.1017 - val_accuracy: 0.9571
# Epoch 30/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0833 - accuracy: 0.9702 - val_loss: 0.0879 - val_accuracy: 0.9643
# Epoch 31/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0840 - accuracy: 0.9672 - val_loss: 0.0760 - val_accuracy: 0.9810
# Epoch 32/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0817 - accuracy: 0.9696 - val_loss: 0.1111 - val_accuracy: 0.9500
# Epoch 33/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0943 - accuracy: 0.9690 - val_loss: 0.0790 - val_accuracy: 0.9786
# Epoch 34/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0892 - accuracy: 0.9672 - val_loss: 0.0919 - val_accuracy: 0.9548
# Epoch 35/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0781 - accuracy: 0.9696 - val_loss: 0.0973 - val_accuracy: 0.9690
# Epoch 36/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0833 - accuracy: 0.9678 - val_loss: 0.0832 - val_accuracy: 0.9643
# Epoch 37/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0855 - accuracy: 0.9678 - val_loss: 0.1462 - val_accuracy: 0.9452
# Epoch 38/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0850 - accuracy: 0.9666 - val_loss: 0.1338 - val_accuracy: 0.9548
# Epoch 39/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0867 - accuracy: 0.9690 - val_loss: 0.0992 - val_accuracy: 0.9643
# Epoch 40/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0779 - accuracy: 0.9738 - val_loss: 0.1076 - val_accuracy: 0.9643
# Epoch 41/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0856 - accuracy: 0.9702 - val_loss: 0.0823 - val_accuracy: 0.9619
# Epoch 42/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0698 - accuracy: 0.9714 - val_loss: 0.0886 - val_accuracy: 0.9667
# Epoch 43/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9678 - val_loss: 0.0739 - val_accuracy: 0.9762
# Epoch 44/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0851 - accuracy: 0.9744 - val_loss: 0.0853 - val_accuracy: 0.9714
# Epoch 45/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0924 - accuracy: 0.9613 - val_loss: 0.1024 - val_accuracy: 0.9595
# Epoch 46/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0883 - accuracy: 0.9672 - val_loss: 0.0689 - val_accuracy: 0.9714
# Epoch 47/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 0.9690 - val_loss: 0.1066 - val_accuracy: 0.9619
# Epoch 48/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9696 - val_loss: 0.0836 - val_accuracy: 0.9690
# Epoch 49/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9696 - val_loss: 0.1004 - val_accuracy: 0.9619
# Epoch 50/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0617 - accuracy: 0.9774 - val_loss: 0.0746 - val_accuracy: 0.9762
# Epoch 51/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0710 - accuracy: 0.9738 - val_loss: 0.0744 - val_accuracy: 0.9762
# Epoch 52/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0602 - accuracy: 0.9774 - val_loss: 0.0717 - val_accuracy: 0.9667
# Epoch 53/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0606 - accuracy: 0.9786 - val_loss: 0.0671 - val_accuracy: 0.9833
# Epoch 54/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0723 - accuracy: 0.9696 - val_loss: 0.0671 - val_accuracy: 0.9762
# Epoch 55/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0604 - accuracy: 0.9762 - val_loss: 0.1088 - val_accuracy: 0.9548
# Epoch 56/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0600 - accuracy: 0.9792 - val_loss: 0.1434 - val_accuracy: 0.9452
# Epoch 57/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0858 - accuracy: 0.9696 - val_loss: 0.0628 - val_accuracy: 0.9714
# Epoch 58/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0568 - accuracy: 0.9815 - val_loss: 0.1076 - val_accuracy: 0.9571
# Epoch 59/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.9732 - val_loss: 0.0631 - val_accuracy: 0.9786
# Epoch 60/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0660 - accuracy: 0.9744 - val_loss: 0.1097 - val_accuracy: 0.9619
# Epoch 61/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0552 - accuracy: 0.9792 - val_loss: 0.0826 - val_accuracy: 0.9619
# Epoch 62/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0647 - accuracy: 0.9738 - val_loss: 0.0586 - val_accuracy: 0.9833
# Epoch 63/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0667 - accuracy: 0.9750 - val_loss: 0.0789 - val_accuracy: 0.9643
# Epoch 64/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0609 - accuracy: 0.9750 - val_loss: 0.0910 - val_accuracy: 0.9714
# Epoch 65/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0587 - accuracy: 0.9750 - val_loss: 0.0747 - val_accuracy: 0.9690
# Epoch 66/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0715 - accuracy: 0.9732 - val_loss: 0.0822 - val_accuracy: 0.9690
# Epoch 67/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0674 - accuracy: 0.9714 - val_loss: 0.0723 - val_accuracy: 0.9690
# Epoch 68/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0763 - accuracy: 0.9690 - val_loss: 0.0675 - val_accuracy: 0.9833
# Epoch 69/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0650 - accuracy: 0.9762 - val_loss: 0.0733 - val_accuracy: 0.9690
# Epoch 70/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0523 - accuracy: 0.9809 - val_loss: 0.0996 - val_accuracy: 0.9548
# Epoch 71/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0614 - accuracy: 0.9768 - val_loss: 0.0882 - val_accuracy: 0.9714
# Epoch 72/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0592 - accuracy: 0.9762 - val_loss: 0.0660 - val_accuracy: 0.9762
# Epoch 73/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0616 - accuracy: 0.9762 - val_loss: 0.0722 - val_accuracy: 0.9810
# Epoch 74/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0566 - accuracy: 0.9768 - val_loss: 0.0786 - val_accuracy: 0.9690
# Epoch 75/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0483 - accuracy: 0.9839 - val_loss: 0.0606 - val_accuracy: 0.9857
# Epoch 76/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0503 - accuracy: 0.9809 - val_loss: 0.0855 - val_accuracy: 0.9643
# Epoch 77/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0469 - accuracy: 0.9833 - val_loss: 0.0759 - val_accuracy: 0.9738
# Epoch 78/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0598 - accuracy: 0.9744 - val_loss: 0.0634 - val_accuracy: 0.9833
# Epoch 79/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0565 - accuracy: 0.9774 - val_loss: 0.1026 - val_accuracy: 0.9548
# Epoch 80/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0603 - accuracy: 0.9774 - val_loss: 0.1194 - val_accuracy: 0.9619
# Epoch 81/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0750 - accuracy: 0.9696 - val_loss: 0.0974 - val_accuracy: 0.9690
# Epoch 82/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0589 - accuracy: 0.9774 - val_loss: 0.1728 - val_accuracy: 0.9476
# Epoch 83/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0793 - accuracy: 0.9720 - val_loss: 0.1013 - val_accuracy: 0.9690
# Epoch 84/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0691 - accuracy: 0.9750 - val_loss: 0.0613 - val_accuracy: 0.9786
# Epoch 85/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0501 - accuracy: 0.9797 - val_loss: 0.0617 - val_accuracy: 0.9667
# Epoch 86/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0454 - accuracy: 0.9827 - val_loss: 0.0729 - val_accuracy: 0.9833
# Epoch 87/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0488 - accuracy: 0.9815 - val_loss: 0.0890 - val_accuracy: 0.9571
# Epoch 88/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0634 - accuracy: 0.9780 - val_loss: 0.0776 - val_accuracy: 0.9690
# Epoch 89/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0538 - accuracy: 0.9786 - val_loss: 0.1187 - val_accuracy: 0.9429
# Epoch 90/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0562 - accuracy: 0.9768 - val_loss: 0.0918 - val_accuracy: 0.9595
# Epoch 91/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0550 - accuracy: 0.9792 - val_loss: 0.0689 - val_accuracy: 0.9786
# Epoch 92/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0699 - accuracy: 0.9708 - val_loss: 0.0873 - val_accuracy: 0.9667
# Epoch 93/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0512 - accuracy: 0.9780 - val_loss: 0.0704 - val_accuracy: 0.9690
# Epoch 94/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0452 - accuracy: 0.9827 - val_loss: 0.0645 - val_accuracy: 0.9810
# Epoch 95/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0457 - accuracy: 0.9827 - val_loss: 0.0531 - val_accuracy: 0.9881
# Epoch 96/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0488 - accuracy: 0.9809 - val_loss: 0.0638 - val_accuracy: 0.9762
# Epoch 97/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9797 - val_loss: 0.0984 - val_accuracy: 0.9643
# Epoch 98/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0539 - accuracy: 0.9762 - val_loss: 0.1253 - val_accuracy: 0.9619
# Epoch 99/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0566 - accuracy: 0.9797 - val_loss: 0.0659 - val_accuracy: 0.9690
# Epoch 100/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0646 - accuracy: 0.9756 - val_loss: 0.0701 - val_accuracy: 0.9690
# 9240
# [[1.5926619e-07 1.5889891e-05 2.0352079e-06 ... 1.1421812e-05
#   2.1686553e-07 4.4037959e-13]
#  [2.2717952e-09 7.2702358e-11 4.5648056e-16 ... 2.2706282e-14
#   9.9999344e-01 6.8838575e-19]
#  [4.8369997e-10 3.5854291e-06 4.2144571e-18 ... 3.5395122e-14
#   2.1179182e-10 1.3275931e-14]
#  ...
#  [3.1572625e-09 3.1382978e-08 1.5777263e-05 ... 2.9204918e-09
#   4.5472424e-11 7.0816981e-12]
#  [1.1013649e-09 2.0197660e-10 2.6549399e-12 ... 5.3176552e-01
#   4.1190465e-06 5.1574281e-17]
#  [5.2150153e-07 4.3282753e-07 1.7571068e-05 ... 8.5714573e-09
#   1.4203236e-07 2.8327920e-11]]

# %%
a=[]
for i in y_pre:
    max = 0
    c=None
    for j in range(len(i)):
        if i[j]>max:
            max=i[j]
            c=j
    a.append(c)

# %%
print(accuracy_score(y_test,a)*100)
print(y_test[35])
print(y_pre[35])
# Out:
# 96.9047619047619
# 19.0
# [9.7819300e-13 2.9070981e-14 2.3438609e-16 5.4013726e-17 3.2731184e-06
#  1.1155801e-03 1.1353573e-06 6.1164442e-11 5.4924651e-03 1.8720736e-13
#  9.6458946e-18 6.2161845e-09 9.6811381e-10 5.0778883e-20 1.0521276e-08
#  1.5403121e-11 2.4806191e-06 3.4259451e-06 1.5831696e-13 9.9338162e-01
#  9.4521418e-08 2.8816525e-19]

# %%
import tkinter as tk
from tkinter import *
from PIL import ImageTk, Image
w1=0
w2=""

# %%
def fr(frame):
    frame.tkraise()
def but():
    n=n1.get()
    p=p2.get()
    k=k1.get()
    t=temp.get()
    h=hum.get()
    ph1=ph.get()
    r=ra.get()
    test = [n, p, k, t, h, ph1, r]
    y_pre = ann.predict([test])
    a = []
    for i in y_pre:
        max = 0
        c = None
        for j in range(len(i)):
            if i[j] > max:
                max = i[j]
                c = j
        a.append(c)
    print(a)
    list1 = []
    global w1,w2
    for i in a:
        for j in le_name:
            if le_name[j] == i:
                list1.append(j)
    w1=a[0]
    w2=list1[0]
    aq1 = tk.Label(p1, text="             ", bg='light blue', font=("Times New Roman", 20))
    aq2 = tk.Label(p1, text="                  ", bg='light blue', font=("Times New Roman", 25))
    aq2.place(relx=.25, rely=.75)
    aq1.place(relx=.25, rely=.65)
    aq1 = tk.Label(p1, text=w1, bg='light blue', font=("Times New Roman", 20))
    aq2 = tk.Label(p1, text=w2, bg='light blue', font=("Times New Roman", 20))
    # aq1.place(relx=.25, rely=.65)
    aq2.place(relx=.25, rely=.75)

    if w1==0:
        path="apple.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1==1:
        path="banana.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 2:
        path="black gram.jpg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 3:
        path="chickpea.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 4:
        path="coconut.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 5:
        path="coffee.jpg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 6:
        path="cotton.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 7:
        path="grapes.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 8:
        path="jute.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 9:
        path="kidney_beans.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 10:
        path="lentils.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 11:
        path="maize.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 12:
        path="mango.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 13:
        path="mothbean.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 14:
        path="mungbean.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 15:
        path="muskmelon.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 16:
        path="orange.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 17:
        path="pigeon peas.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 18:
        path="pomegranate.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 19:
        path="rice.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)
    elif w1 == 20:
        path="watermelon.jpeg"
        q = Image.open(path)
        img1 = q.resize((200, 200))
        img = ImageTk.PhotoImage(img1)
        panel = Label(p1, image=img)
        panel.photo = img
        panel.place(relx=.5, rely=.65)

# %%
win=tk.Tk()
win.title("Crop Recommender")
win.geometry('600x550')
win.rowconfigure(0, weight=1)
win.columnconfigure(0, weight=1)
n1= tk.DoubleVar()
p2 = tk.DoubleVar()
k1 = tk.DoubleVar()
temp = tk.DoubleVar()
hum= tk.DoubleVar()
ph = tk.DoubleVar()
ra = tk.DoubleVar()
p1 = tk.Frame(win,width=200, height=100,bg='light blue')
p1.grid(row=0, column=0, sticky='nsew')

# %%
h1=tk.Label(p1,text="CROP RECOMMENDATION",bg='light blue', font=("Times New Roman", 20)).place(relx=.25, rely=.05)

q1=tk.Label(p1,text="NITROGEN : ",bg='light blue', font=("Times New Roman", 20)).place(relx=.15, rely=.15)
e1=tk.Entry(p1, textvariable=n1, width=25,highlightbackground='light blue').place(relx=.399, rely=.15)

q2=tk.Label(p1,text="PHOSPHORUS : ",bg='light blue', font=("Times New Roman", 20)).place(relx=.15, rely=.2)
e2=tk.Entry(p1, textvariable=p2, width=25,highlightbackground='light blue').place(relx=.399, rely=.2)

q3=tk.Label(p1,text="POTASSIUM : ",bg='light blue', font=("Times New Roman", 20)).place(relx=.15, rely=.25)
e3=tk.Entry(p1, textvariable=k1, width=25,highlightbackground='light blue').place(relx=.399, rely=.25)

q4=tk.Label(p1,text="TEMPERATURE : ",bg='light blue', font=("Times New Roman", 20)).place(relx=.15, rely=.3)
e4=tk.Entry(p1, textvariable=temp, width=25,highlightbackground='light blue').place(relx=.399, rely=.3)

q5=tk.Label(p1,text="HUMIDITY : ",bg='light blue', font=("Times New Roman", 20)).place(relx=.15, rely=.35)
e5=tk.Entry(p1, textvariable=hum, width=25,highlightbackground='light blue').place(relx=.399, rely=.35)

q6=tk.Label(p1,text="PH : ",bg='light blue', font=("Times New Roman", 20)).place(relx=.15, rely=.4)
e6=tk.Entry(p1, textvariable=ph, width=25,highlightbackground='light blue').place(relx=.399, rely=.4)

q7=tk.Label(p1,text="RAINFALL : ",bg='light blue', font=("Times New Roman", 20)).place(relx=.15, rely=.45)
e7=tk.Entry(p1, textvariable=ra, width=25,highlightbackground='light blue').place(relx=.399, rely=.45)

b1=tk.Button(p1,text="SUBMIT",width=25,height=2,highlightbackground='light blue',fg="yellow",command=lambda:but()).place(relx=.25, rely=.55)
# lbl_result= tk.Label(p1, text="jab").grid(row=1,column=5)

# %%
fr(p1)
win.mainloop()
# Out:
# [12]
